# %%
import pandas as pd
import yfinance as yf

data = pd.Series([100, 102, 101, 105, 107])

# Calculate the daily price change
delta = data.diff()

gain = (delta.where(delta > 0, 0)).rolling(window=4).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=4).mean()

print(delta)
print(gain)
print(loss)
# Out:
# 0    NaN
# 1    2.0
# 2   -1.0
# 3    4.0
# 4    2.0
# dtype: float64
# 0    NaN
# 1    NaN
# 2    NaN
# 3    1.5
# 4    2.0
# dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3    0.25
# 4    0.25
# dtype: float64

# %%
def calculate_adr(data, window=4):
    high_low = data['High'] - data['Low']
    adr = high_low.rolling(window=window).mean()
    return adr

# %%
import yfinance as yf
import pandas as pd

def calculate_rsi(data, window=4):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()

    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rs

# data = yf.download('MMM',period='15d')
# calculate_rsi(data)


# #     "AAPL", "ABBV", "ABT", "ACN", "ADBE", "AIG", "ALL", 
# #                  "AMGN", "AMT", "AMZN", "AXP", "BA", "BAC", "BIIB", 
# #                  "BK", "BKNG", "BLK", "BMY", "C", "CAT", "CHTR", 
# #                  "CL", "CMCSA", "COF", "COP", "COST", "CRM", "CSCO", 
# #                  "CVS", "CVX", "DD", "DHR", "DIS", "DOW", "DUK", 
# #                  "EMR", "EXC", "F", "META", "FDX", "GD", "GE", 
# #                  "GILD", "GM", "GOOG", "GOOGL", "GS", "HD", "HON", 
# #                  "IBM", "INTC", "JNJ", "JPM", "KHC", "KMI", "KO", 
# #                  "LLY", "LMT", "LOW", "MA", "MCD", "MDLZ", "MDT", 
# #                  "MET", "MMM", "MO", "MRK", "MS", "MSFT"]

# # 
# # Initialize a list to store stocks that meet the entry criteria
# stocks_meeting_criteria = []

# for ticker in sp100_tickers:
#     data = yf.download(ticker,period='15d',Interval='1d')  # Fetch data for the last 5 days
#     data['RSI'] = calculate_rsi(data['Close'])
# #     print(data['RSI'])
#     # Check if the last day's RSI is below 15
# #     if data['RSI'].iloc[-1] < 15 and data['Close'].iloc[-1] < 100:
# #         stocks_meeting_criteria.append(ticker)

# print(stocks_meeting_criteria)

# %%
data = yf.download('MMM')
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 1962-01-02   0.000000   4.250000   4.125000   4.156250   0.702820   212800
# 1962-01-03   0.000000   4.187500   4.085938   4.187500   0.708104   422400
# 1962-01-04   0.000000   4.257813   4.187500   4.187500   0.708104   212800
# 1962-01-05   0.000000   4.171875   4.062500   4.078125   0.689608   315200
# 1962-01-08   0.000000   4.085938   4.031250   4.054688   0.685646   334400
# ...               ...        ...        ...        ...        ...      ...
# 2024-01-26  96.220001  96.900002  95.790001  95.989998  95.989998  3720200
# 2024-01-29  96.000000  96.889999  95.440002  96.379997  96.379997  3800000
# 2024-01-30  96.169998  96.510002  94.779999  95.750000  95.750000  3200500
# 2024-01-31  95.940002  95.940002  94.160004  94.349998  94.349998  6905400
# ...

# %%
# !pip install ta
# Out:
# ...
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29430 sha256=98af34b927cdf4680d61aec2b5b5636bdea4e5e37f605671ddef951740a617f2
#   Stored in directory: /Users/snigdha/Library/Caches/pip/wheels/61/d8/66/8018676d483fa5edb5337a7a25ee8c029ac255be25f90f3cd5
# Successfully built ta
# ...

# %%
import yfinance as yf
from ta.momentum import RSIIndicator
import pandas as pd


# ticker_symbol = 'AAPL' 

# tickers = ["AAPL", "ABBV", "ABT", "ACN", "ADBE", "AIG", "ALL", 
#                  "AMGN", "AMT", "AMZN", "AXP", "BA", "BAC", "BIIB", 
#                  "BK", "BKNG", "BLK", "BMY", "C", "CAT", "CHTR", 
#                  "CL", "CMCSA", "COF", "COP", "COST", "CRM", "CSCO", 
#                  "CVS", "CVX", "DD", "DHR", "DIS", "DOW", "DUK", 
#                  "EMR", "EXC", "F", "META", "FDX", "GD", "GE", 
#                  "GILD", "GM", "GOOG", "GOOGL", "GS", "HD", "HON", 
#                  "IBM", "INTC", "JNJ", "JPM", "KHC", "KMI", "KO", 
#                  "LLY", "LMT", "LOW", "MA", "MCD", "MDLZ", "MDT", 
#                  "MET", "MMM", "MO", "MRK", "MS", "MSFT"]

tickers = ["MMM","MET","DD","GILD"]

stocks_meeting_criteria = []

for ticker in tickers:
    data = yf.download(ticker,period='100d')  # Fetch data for the last 5 days
    rsi = RSIIndicator(data['Close'], window=4).rsi()
    data['RSI_4'] = rsi
    RSI4 = data.tail(1)['RSI_4'].iloc[-1]
    Cls_P = data['Close'].iloc[-1]
    print(f"{ticker} has rsi {RSI4} and closing price {Cls_P}")
    if RSI4 < 15 :
        stocks_meeting_criteria.append(ticker)

print(stocks_meeting_criteria)


# data = yf.download(ticker_symbol, start="2023-01-01", end="2024-02-02")

# rsi = RSIIndicator(data['Close'], window=4).rsi()

# data['RSI_4'] = rsi

# RSI4 = data.tail(1)['RSI_4'].iloc[-1]
# Cls_P = data['Close'].iloc[-1]


# print(data.tail(1)['RSI_4'].iloc[-1])

# if RSI4 < 15 and Cls_P < 100:
#     print("YES")
# else:
#     print("NO")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# MMM has rsi 32.455480910821635 and closing price 94.64869689941406
# MET has rsi 20.974595681641503 and closing price 65.81999969482422
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# DD has rsi 9.547110899796536 and closing price 61.20000076293945
# GILD has rsi 15.29161787746932 and closing price 77.63999938964844
# ['DD']
